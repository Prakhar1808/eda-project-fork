# %% [markdown]
# BASICS

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x= np.linspace(0,5,11)
x
y= x **3
y
# Out:
# array([  0.   ,   0.125,   1.   ,   3.375,   8.   ,  15.625,  27.   ,
#         42.875,  64.   ,  91.125, 125.   ])

# %%
plt.plot(x,y)
plt.title("PLOT OF X VS Y")
plt.xlabel("X AXIS")
plt.ylabel("Y AXIS")
# Out:
# Text(0, 0.5, 'Y AXIS')

# %% [markdown]
# SUBPLOTS

# %%
plt.subplot(2,2,1)
plt.plot(x,y)
plt.subplot(2,2,2)
plt.plot(y,x)
plt.subplot(2,2,3)
plt.plot(x,x**2)
plt.subplot(2,2,4)
plt.plot(y,y**2)

# %% [markdown]
# OBJECT OREINTATED WAY

# %%
fig= plt.figure()
axis1=fig.add_axes([0.1,0.1,0.8,0.8])  # left,bottom,width,height
axis1.plot(x,y)
axis2=fig.add_axes([0.3,0.5,0.2,0.2])  # left,bottom,width,height
axis2.plot(y,x)
plt.savefig("1st_plot.png")

# %% [markdown]
# TYPES OF PLOTS

# %%
plt.scatter(x,y)  # scatter plot

# %%
plt.hist(x)  # histogram
# Out:
# (array([1., 1., 1., 1., 1., 1., 1., 1., 1., 2.]),
#  array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(y)  # box plot
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x21afd3dda80>,
#   <matplotlib.lines.Line2D at 0x21afd3ddd80>],
#  'caps': [<matplotlib.lines.Line2D at 0x21afd3de080>,
#   <matplotlib.lines.Line2D at 0x21afd3de380>],
#  'boxes': [<matplotlib.lines.Line2D at 0x21afd3dd8a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x21afd3de680>],
#  'fliers': [<matplotlib.lines.Line2D at 0x21afd3de980>],
#  'means': []}

# %% [markdown]
# WORKING WITH IMAGES

# %%
import matplotlib.image as mpimg
img= mpimg.imread("1st_plot.png")
plt.imshow(img)
